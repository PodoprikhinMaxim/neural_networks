# %% [markdown]
# ## Семинар 1 "Полносвязные нейронные сети"

# %% [markdown]
# ФИО: Подоприхин Максим Александрович

# %% [markdown]
# В этом задании вам предстоит реализовать проход "вперед" для полносвязной нейронную сети. В дальнейшем мы реализуем процедуру обучения и научим сеть распознавать рукописные цифры.
#
# На первой лекции мы познакомились с тем, что такое нейронные сети и изучили три слоя — линейный, сигмоида и SoftMax. Из этих слоев можно составлять глубокие архитектуры и обучать их при помощи градиентного спуска. Чтобы конструировать сложные архитектуры, можно реализовать каждый тип слоя как отдельный "кирпичик" и затем собирать полную архитектуру как конструктор. Это мы и попробуем сделать на первом и втором семинарах.

# %% [markdown]
# Каждый тип слоя мы будем реализовывать при помощи класса, который будет поддерживать три функции: forward, которая будет применять функцию, реализуемую слоем, к входной матрице и backward, которая будет вычислять градиенты и step, которая будет обновлять веса. Чтобы не применять функцию к каждому объекту в отдельности, мы будем подавать на вход слою матрицу размера (N, d), где N — количество объектов, а d — размерность каждого объекта.

# %% [markdown]
# <img src=backprop.pdf width=400/>

# %% [markdown]
# Функция forward будет вычислять по $x$ значение $y$, backward — по $\frac{\partial L}{\partial y}$ вычислять $\frac{\partial L}{\partial x}$ и обновлять внутри себя $\frac{\partial L}{\partial w}$.
#
# Важным требованием к реализации является векторизация всех слоев: все операции должны быть сведены к матричным, не должно быть циклов. Это значительно уменьшает временные затраты.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Часть 1: Линейный слой

# %% [markdown]
# Приведем пример вычисления градиентов для линейного слоя: $y = Wx$, $x \in \mathbb{R}^{K \times n}$, $y \in \mathbb{R}^{K \times n}$, $W \in \mathbb{R}^{n \times m}$, где $K$ — число объектов.
#
# Рассмотрим $L$ как функцию от выходов нейронной сети: $L = L(y_{11}, y_{12}, \dots)$
#
# $$y_{kt} = (Wx)_{kt} = \sum_{z=1}^{n} x_{kz}W_{zt}$$
#
# $$\frac{\partial L}{\partial x_{ij}} = \sum_{kt} \frac{\partial L}{\partial y_{kt}}\frac{\partial y_{kt}}{\partial x_{ij}} = \sum_{kt} \frac{\partial L}{\partial y_{kt}}\frac{\partial \sum_z x_{kz}w_{zt}}{\partial x_{ij}}= \sum_{t} \frac{\partial L}{\partial y_{it}}\frac{\partial w_{jt}}{\partial x_{ij}}$$
#
# $$\frac{\partial{L}}{\partial x} = \frac{\partial{L}}{\partial y}W^T$$

# %%
class Linear:
    def __init__(self, input_size, output_size):
        '''
        Creates weights and biases for linear layer.
        Dimention of inputs is *input_size*, of output: *output_size*.
        '''
        #### YOUR CODE HERE
        #### Create weights, initialize them with samples from N(0, 0.1).
        self.W = np.random.randn(input_size, output_size) * 0.1
        self.b = np.zeros(output_size)
        pass
    
    def forward(self, X):
        '''
        Passes objects through this layer.
        X is np.array of size (N, input_size).
        Returns output of size (N, output_size).
        Hint: You may need to store X for backward pass
        '''
        #### YOUR CODE HERE
        #### Apply layer to input
        #print("forward")
        self.X = X
        self.Y = X @ self.W + self.b ## @ same as .dot()
        return self.Y
    
    def backward(self, dLdy):
        '''
        1. Compute dLdw and dLdx.
        2. Store dLdw for step() call
        3. Return dLdx
        '''
        #### YOUR CODE HERE
        #print("backward")
        self.dLdW = self.X.T.dot(dLdy)
        self.dLdb = dLdy.sum(0)
        self.dLdx = dLdy.dot(self.W.T)
        return self.dLdx
    
    def step(self, learning_rate):
        '''
        1. Apply gradient dLdw to network:
        w <- w - l*dLdw
        '''
        #### YOUR CODE HERE
        #print("step")
        self.W = self.W - learning_rate * self.dLdW
        self.b = self.b - learning_rate * self.dLdb
        return self.W, self.b

# %% [markdown]
# ### Часть 2: Численный градиент

# %% [markdown]
# Релизуйте функцию проверки численного градиента. Для этого для каждой переменной, по которой считается градиент, надо вычислить численный градиент: $f'(x) \approx \frac{f(x+\epsilon)-f(x-\epsilon)}{2\epsilon}$. Функция должна возвращать максимальное абсолютное отклонение аналитического градиента от численного. В качестве $\epsilon$ рекомендуется взять $10^{-6}$. При правильной реализации максимальное отличие будет иметь порядок $10^{-8}-10^{-6}$.

# %%
def check_gradient(func, X, gradient):
    '''
    Computes numerical gradient and compares it with analytcal.
    func: callable, function of which gradient we are interested. Example call: func(X)
    X: np.array of size (n x m)
    gradient: np.array of size (n x m)
    Returns: maximum absolute diviation between numerical gradient and analytical.
    '''
    eps = 10**(-5)
    
    f_grad = np.zeros(gradient.shape)
    
    for i in range(X.shape[0]):
        for j in range(X.shape[1]):
            X[i, j] += eps            
            f_r = func(X)
            X[i, j] -= 2*eps            
            f_l = func(X)            
            X[i, j] += eps
                    
            f_grad[i, j] = (f_r - f_l) / 2 / eps
    
    return np.max(np.abs(gradient - f_grad))

# %%
np.random.seed(777)
x = np.random.rand(10, 20)
func = lambda x: (x**2).sum()
gradient = 2*x
check_gradient(func, x, gradient)
# Out:
# 5.662181834509283e-10

# %% [markdown]
# Протестируйте линейный слой при помощи реализованной функции check_gradient: $\frac{\partial L}{\partial x}$ и $\frac{\partial L}{\partial w}$.

# %%
np.random.seed(777)

X = np.array([[0, 1], [1, 1]])
Y = np.array([[0], [1]])

l = Linear(2, 1)

def loss(W):
    l.W = W
    
    res = l.forward(X)
    
    return np.sum((res - Y)**2)

res = l.forward(X)
print(res)
dLdy = 2*(res - Y)
print(dLdy)

l.backward(dLdy)

print(l.dLdW)

check_gradient(loss, l.W, l.dLdW)
# Out:
# [[-0.08228249]
#  [-0.12910336]]
# [[-0.16456497]
#  [-2.25820673]]
# [[-2.25820673]
#  [-2.4227717 ]]
# 1.099031976536935e-11

# %% [markdown]
# ### Часть 3: Сигмоида

# %%
class Sigmoid:
    def __init__(self):
        pass
    
    def forward(self, X):
        '''
        Passes objects through this layer.
        X is np.array of size (N, d)
        '''
        #### YOUR CODE HERE
        #### Apply layer to input
        self.X = X
        return 1 / (1 + np.exp(-X))
    
    def backward(self, dLdy):
        '''
        1. Compute dLdx.
        2. Return dLdx
        '''
        #### YOUR CODE HERE
        self.dLdx = dLdy * self.forward(self.X) * (1 - self.forward(self.X)) 
        return self.dLdx
    
    def step(self, learning_rate):
        pass

# %% [markdown]
# Протестируйте слой при помощи реализованной функции check_gradient: $\frac{\partial L}{\partial x}$.

# %%
X = np.ones((5, 10))
s = Sigmoid()
def func(X):
    return s.forward(X).sum()

dLdy = np.ones((5, 10))
s.forward(X)
gradient = s.backward(dLdy)
check_gradient(func, X, gradient)
# Out:
# 1.0723213983432345e-10

# %% [markdown]
# ### Часть 4: Функция потерь

# %% [markdown]
# Как мы увидели на семинаре, вычисление производной для связки SoftMax + Negative log-likelihood проще чем для этих двух слоев по отдельности. Поэтому мы реализуем их как один класс. Важное замечание: на проходе "вперед" важно воспользоваться трюком <a href="https://blog.feedly.com/tricks-of-the-trade-logsumexp/">log-sum-exp</a>, чтобы не столкнуться с численными неустойчивостями.

# %%
class NLLLoss:
    def __init__(self):
        '''
        Applies Softmax operation to inputs and computes NLL loss
        '''
        #### YOUR CODE HERE
        #### (Hint: No code is expected here, just joking)
        pass
    
    def forward(self, X, y):
        '''
        Passes objects through this layer.
        X is np.array of size (N, C), where C is the number of classes
        y is np.array of size (N), contains correct labels
        '''
        #### YOUR CODE HERE
        #### Apply layer to input
        self.p = np.exp(X)
        self.p /= self.p.sum(1, keepdims=True)
        self.y = np.zeros((X.shape[0], X.shape[1]))
        self.y[np.arange(X.shape[0]), y] = 1
        return -(np.log(self.p)*self.y).sum(1).mean(0)

    def backward(self):
        '''
        Note that here dLdy = 1 since L = y
        1. Compute dLdx
        2. Return dLdx
        '''
        #### YOUR CODE HERE
        return (self.p - self.y) / self.y.shape[0]

# %% [markdown]
# Протестируйте слой при помощи реализованной функции check_gradient: $\frac{\partial L}{\partial x}$.

# %%
#### YOUR CODE HERE
X = np.random.rand(10, 4)
y = np.random.randint(0, 4, 10)
clf = NLLLoss()
clf.forward(X, y)
fun = lambda x: clf.forward(x, y)
check_gradient(fun, X, clf.backward())
# Out:
# 2.6050470808280934e-11

# %% [markdown]
# ### Часть 5, нейронная сеть

# %% [markdown]
# Теперь, когда у нас есть "кирпичики", мы можем написать класс, который будет собирать всю сеть вместе

# %%
class NeuralNetwork:
    def __init__(self, modules):
        '''
        Constructs network with *modules* as its layers
        '''
        #### YOUR CODE HERE
        self.modules = modules

    def forward(self, X):
        #### YOUR CODE HERE
        #### Apply layers to input
        self.X = X
        y = X
        for module in self.modules:
            y = module.forward(y)
        return y
    
    def backward(self, dLdy):
        '''
        dLdy here is a gradient from loss function
        '''
        #### YOUR CODE HERE
        for i in range(len(self.modules))[::-1]:
            dLdy = self.modules[i].backward(dLdy)
        return dLdy
    
    def step(self, learning_rate):
        for module in self.modules:
            module.step(learning_rate)

# %% [markdown]
# ### Часть 6, обучение на простых данных

# %%
data = np.load('data.npz')
X, y = data['arr_0'], data['arr_1']
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.axis('equal')
plt.show()

# %% [markdown]
# Обучите архитектуру вида 2 -> 10 -> 10 -> 3:
# * Linear(2, 10)
# * Sigmoid()
# * Linear(10, 10)
# * Sigmoid()
# * Linear(10, 3)
#
# В качестве функции потерь используйте NLLLoss.
# 1. Создайте сеть, в цикле запускайте forward, backward, step (используйте learning rate 0.005).
# 2. Нарисуйте график сходимости (величина NLL после каждого обновления).
# 3. Нарисуйте разделяющую поверхность
# 4. Попробуйте подобрать темп обучения. Как меняется сходимость?

# %% [markdown]
# Отличная визуализация: http://playground.tensorflow.org/

# %%
### YOUR CODE HERE:#bad idea
activation = Sigmoid()

inner_dim = 10

layers = [Linear(2, inner_dim), activation]
for i in range(1):
    layers.extend([Linear(inner_dim, inner_dim), activation])

layers.append(Linear(inner_dim, 3))
for i in range(len(layers)):
    print(layers[i])
net = NeuralNetwork(layers)
loss = NLLLoss()
# Out:
# <__main__.Linear object at 0x7f30a9f530d0>
# <__main__.Sigmoid object at 0x7f30a9f53bd0>
# <__main__.Linear object at 0x7f30a9f53150>
# <__main__.Sigmoid object at 0x7f30a9f53bd0>
# <__main__.Linear object at 0x7f30a9f53850>

# %%
losses = []
epoch = 15000
learning_rate = 0.08
for i in range(epoch):
    res = net.forward(X)
    l = loss.forward(res, y)
    losses.append(l)
    dLdy = loss.backward()
    
    net.backward(dLdy)
    net.step(learning_rate)

# %%
plt.plot(losses)

# %%
N = 50
x_grid = np.linspace(-0.2, 1.2, N)
y_grid = np.linspace(0, 1, N)

# %%
X_mesh, Y_mesh = np.meshgrid(x_grid, y_grid)

# %%
mesh = np.dstack((X_mesh, Y_mesh)).reshape(N*N, 2)
predictions = np.argmax(net.forward(mesh), 1)

# %%
plt.scatter(mesh[:, 0], mesh[:, 1], c=predictions, alpha=0.2)
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Домашнее задание:

# %% [markdown]
# * Подоберите темп обучения. Как меняется сходимость? Нарисуйте график оптимального значения функции потерь для различных значений learning_rate
# * Решите поставленную выше задачу как задачу регрессии с MSE. Изменилась ли разделяющая поверхность?

# %%
list_of_losses = []
learning_rates = np.linspace(0.05, 1, 10)
for rate in learning_rates:
    losses = []
    for i in range(15000):
        predict = net.forward(X)
        l = loss.forward(predict, y)
        losses.append(l)
        dLdy = loss.backward()
        net.backward(dLdy)
        net.step(rate)
    list_of_losses.append(losses)
    print(rate)
# Out:
# 0.05
# 0.15555555555555556
# 0.2611111111111111
# 0.36666666666666664
# 0.4722222222222222
# 0.5777777777777778
# 0.6833333333333333
# 0.788888888888889
# 0.8944444444444445
# 1.0

# %%
legends = []
for i in range(10):
    plt.plot(list_of_losses[i])
    legends.append("rate =" + str(round(learning_rates[i], 3)))
plt.legend(legends)
plt.show()

# %%
legends = []
for i in range(3):
    plt.plot(list_of_losses[i])
    legends.append("rate =" + str(round(learning_rates[i], 3)))
plt.legend(legends)
plt.show()

# %%
legends = []
for i in range(3, 7):
    plt.plot(list_of_losses[i])
    legends.append("rate =" + str(round(learning_rates[i], 3)))
plt.legend(legends)
plt.show()

# %%
legends = []
for i in range(7, 10):
    plt.plot(list_of_losses[i])
    legends.append("rate =" + str(round(learning_rates[i], 3)))
plt.legend(legends)
plt.show()

# %% [markdown]
# Как мы, видим, оптимальный темп обучения - 0.367, на нем сходимость лучше. (сходимость сначала становится лучше, потом хуже).

# %%
class MSELoss:
    def __init__(self):
        '''
        Computes MSE loss
        '''
        pass
    
    def forward(self, X, y):
        '''
        Passes objects through this layer.
        X is np.array of size (N, C), where C is the number of classes
        y is np.array of size (N), contains correct labels
        '''
        self.p = np.exp(X)
        self.p /= self.p.sum(1, keepdims=True)
        self.y = np.zeros((X.shape[0], X.shape[1]))
        self.y[np.arange(X.shape[0]), y] = 1
        return  ((self.p - self.y) ** 2).sum(1).mean(0)
    
    def backward(self):
        '''
        Note that here dLdy = 1 since L = y
        1. Compute dLdx
        2. Return dLdx
        '''
        return 2 * self.p * (1 - self.p) * (self.p - self.y) / self.y.shape[0]

# %%
arc = [Linear(2, 10), Sigmoid(), Linear(10,10),
       Sigmoid(), Linear(10,3)]
network = NeuralNetwork(arc)
loss_func = MSELoss()

# %%
for i in range(15000):
        predict = network.forward(X)
        loss = loss_func.forward(predict, y)
        losses.append(loss)
        dLdy = loss_func.backward()
        network.backward(dLdy)
        network.step(0.5)

# %%
mesh = np.dstack((X_mesh, Y_mesh)).reshape(N*N, 2)
predictions = np.argmax(network.forward(mesh), 1)

# %%
plt.scatter(mesh[:, 0], mesh[:, 1], c=predictions, alpha=0.2)
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.axis('equal')
plt.show()

# %% [markdown]
# Разделяющие повернхости почти не изменились
